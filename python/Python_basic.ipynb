# %%
a = 12

# %%
print(a)
# Out:
# 12

# %%
print(id(a))
# Out:
# 103302184645896

# %%
b = 12

# %%
print(id(b))
# Out:
# 103302184645896

# %%
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # String Operations

# %%
data = " Vikas Singh   "

# %%
type(data)
# Out:
# str

# %%
data.strip()
# Out:
# 'Vikas Singh'

# %%
"Vikas Singh ".strip()
# Out:
# 'Vikas Singh'

# %%
data.lstrip()
# Out:
# 'Vikas Singh   '

# %%
data.rstrip()
# Out:
# ' Vikas Singh'

# %%
data = "#Vikas Singh__"
data.rstrip("_")
# Out:
# '#Vikas Singh'

# %%
data.lstrip("#")
# Out:
# 'Vikas Singh__'

# %%
data.strip("_#")
# Out:
# 'Vikas Singh'

# %% [markdown]
# Opaerators

# %%
# 1. Relational
print("10>=20", 10>=20)
print("10<=20", 10<=20)
print("10==20", 10==20)
print("10!=20", 10!=20)
# Out:
# 10>=20 False
# 10<=20 True
# 10==20 False
# 10!=20 True

# %%
# 2, Assignment.
a = 2

# %%
a/=2
print(a)
# Out:
# 1.0

# %%
a=/2
# Out:
#   Cell In[19], line 1
#     a=/2
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Output

# %%
print("Vikas Singh")
# Out:
# Vikas Singh

# %%
print("Vikas Singh","Ishu Singh")
# Out:
# Vikas Singh Ishu Singh

# %%
print("Vikas Singh")
print("Ishu Singh")
# Out:
# Vikas Singh
# Ishu Singh

# %%
print("Vikas Singh", end = '--')
print("Ishu Singh")
# Out:
# Vikas Singh--Ishu Singh

# %%
## sep used to put some value between space.
print("Vikas Singh","Ishu Singh", sep = '#')
# Out:
# Vikas Singh#Ishu Singh

# %%
name = input("Enter Your Name : ")
print(name)
# Out:
# Vikas
