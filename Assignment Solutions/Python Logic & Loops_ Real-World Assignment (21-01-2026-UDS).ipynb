# %% [markdown]
# 1. The Office Door Badge You are programming a smart door for a tech office. The door should only open if the
# user provides the correct "Access Code."
# - Input: User enters a 4-digit code.
# - Scenario: If the code is Security Alerted.
# 1234 , print "Access Granted. Door Unlocked." Otherwise, print "Access Denied".

# %%
code = int(input("Enter a 4-digit code: "))
if code == 1234:
    print("Access Granted. Door Unlocked.")
else:
  print("Access Denied")
# Out:
# Enter a 4-digit code: 2345
# Access Denied

# %%
if int(input("Enter a 4-digit code: ")) == 1234:
    print("Access Granted. Door Unlocked.")
else:
  print("Access Denied")
# Out:
# Enter a 4-digit code: 2345
# Access Denied

# %% [markdown]
# 2. The Weekend Grocery Trip A person is deciding whether to go to the supermarket.
# - Input: User enters how many eggs are left in the fridge (integer).
# - Scenario: If the number of eggs is less than 3, print "Time to go to the market!" Else, print "You have
# enough for breakfast today."

# %%
if int(input("Enter eggs left : ")) <= 3:
    print("Time to go to the market.")
else:
  print("You have enough for breakfast today.")
# Out:
# Enter eggs left : 4
# You have enough for breakfast today.

# %% [markdown]
# 3. The Smart Home "Leaving for Work" Checklist When you leave your house, a smart assistant checks multiple
# independent things. These are not mutually exclusive.
# - Input: Three separate inputs (Yes/No) for: "Is the AC on?", "Is the Coffee Maker on?", "Is the Front Door
# unlocked?"
# - Scenario:
#     - If AC is on Print "Turning off AC to save energy."
#     - If Coffee Maker is on Print "Warning: Coffee Maker is still hot!"
#     - If Door is unlocked Print "Locking the front door now." (Note: All three messages could potentially print.)

# %%
ac, coffee, door = input("Is the AC on? "), input("Is the Coffee Maker on? "), input("Is the Front Door unlocked? ")
if ac == "yes":
    print("Turning off AC to save energy.")
if coffee == "yes":
    print("Warning: Coffee Maker is still hot!")
if door == "yes":
    print("Locking the front door now.")
# Out:
# Is the AC on? no
# Is the Coffee Maker on? yes
# Is the Front Door unlocked? yes
# Warning: Coffee Maker is still hot!
# Locking the front door now.

# %% [markdown]
# 4. The Pizza Topping Calculator A customer is choosing toppings. Each topping adds a specific cost regardless of
# the other toppings chosen.
# - Input: Three boolean (True/False) inputs for: Scenario: Initialize a total
# bill = 10.
# extra_cheese , pepperoni , and olives.
#   - If extra_cheese is True add 2 to bill.
#
#
#   - If pepperoni is True add 3 to bill.
#   - If olives is True add 1 to bill.
# Output: Print the final total bill.

# %%
bill = 10
extra_cheese = input("Extra cheese? (yes/no): ").lower() in ('yes', 'true')
pepperoni = input("Pepperoni? (yes/no): ").lower() in ('yes', 'true')
olives = input("Olives? (yes/no): ").lower() in ('yes', 'true')


if extra_cheese:
    bill += 2
if pepperoni:
    bill += 3
if olives:
    bill += 1
print('Total Bill : ', bill)
# Out:
# Extra cheese? (yes/no): yes
# Pepperoni? (yes/no): yes
# Olives? (yes/no): yes
# Extra cheese: True, Pepperoni: True, Olives: True
# Total Bill :  16

# %% [markdown]
# 5. The Traffic Light Sensor A self-driving car needs to interpret a single traffic light color.
# - Input: User enters "Red", "Yellow", or "Green".
# - Scenario:
#   - If "Red" "Full Stop."
#   - If "Yellow" "Slow down and prepare to stop."
#   - If "Green" "Proceed with caution."
#   - Anything else "Error: Signal Malfunction!"

# %%
colour = input("Enter traffic light colour (Red, Yellow or Green): ").lower().strip()
if colour == "red":
    print("Full Stop.")
elif colour == "yellow":
    print("Slow down and prepare to stop.")
elif colour == "green":
    print("Proceed with caution.")
else:
    print("Error: Signal Malfunction!")
# Out:
# Enter traffic light colour (Red, Yellow or Green): green
# Proceed with caution.

# %% [markdown]
# 6. Movie Theater Ticket Pricing A theater charges based on the age of the customer.
# - Input: User enters their age.
# - Scenario:
#     - Age < 5 "Ticket is Free."
#     - Age 5 to 17 "Child Ticket: $10."
#
#     - Age 18 to 60 "Adult Ticket: $18."
#
#     - Age > 60 "Senior Ticket: $12."

# %%
age = int(input("Enter your age: "))
if age < 5:
    print("Ticket is Free.")
elif age >= 5 and age <= 17:
    print("Child Ticket: $10.")
elif age >= 18 and age <= 60:
    print("Adult Ticket: $18.")
else:
    print("Senior Ticket: $12.")
# Out:
# Enter your age: 10
# Child Ticket: $10.

# %% [markdown]
# 7. The 7-Day Steps Tracker A fitness app wants to show your activity for the week.
# - Data: A list of steps: [4000, 7500, 10000, 2000, 8000, 12000, 5000].
# - Scenario: Loop through the list and for each day, print: "Day [X]: You walked [Steps] steps."

# %%
day_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
steps = [4000, 7500, 10000, 2000, 8000, 12000, 5000]
for i in range(len(day_of_week)):
    print("Day ",i+1, day_of_week[i], ": You walked ", steps[i], " steps.")
# Out:
# Day  1 Monday : You walked  4000  steps.
# Day  2 Tuesday : You walked  7500  steps.
# Day  3 Wednesday : You walked  10000  steps.
# Day  4 Thursday : You walked  2000  steps.
# Day  5 Friday : You walked  8000  steps.
# Day  6 Saturday : You walked  12000  steps.
# Day  7 Sunday : You walked  5000  steps.

# %% [markdown]
# 8. The Email "Bcc" System A marketing manager has a list of 5 client names.
# - Input: A list containing 5 names.
# - Scenario: Use a loop to "send" an email to each person by printing: "Sending personalized promo code to
# [Name]..."

# %%
names = ["Vikas", "Isha", "Chahat", "Baldeep", "Nikita"]
for name in names:
    print("Sending personalized promo code to", name, "...")
# Out:
# Sending personalized promo code to Vikas ...
# Sending personalized promo code to Isha ...
# Sending personalized promo code to Chahat ...
# Sending personalized promo code to Baldeep ...
# Sending personalized promo code to Nikita ...
